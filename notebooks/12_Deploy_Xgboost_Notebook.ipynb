# %%
# Authenticate with Docker Registry
# !gcloud auth configure-docker --quiet

# Create a /tmp directory (needed in next steps)
# !mkdir /tmp
# Out:
# WARNING: `docker` not in system PATH.
# `docker` and `docker-credential-gcloud` need to be in the same PATH in order to work correctly together.
# gcloud's Docker credential helper can be configured but it will not work until this is corrected.
# Docker configuration file updated.

# %%
# !pip install sklearn pandas xgboost fairing
# Out:
# Collecting sklearn
#   Downloading https://files.pythonhosted.org/packages/1e/7a/dbb3be0ce9bd5c8b7e3d87328e79063f8b263b2b1bfa4774cb1147bfcd3f/sklearn-0.0.tar.gz
# Requirement already satisfied: pandas in /opt/conda/lib/python3.6/site-packages (0.24.2)
# Requirement already satisfied: xgboost in /opt/conda/lib/python3.6/site-packages (0.82)
# Requirement already satisfied: fairing in /opt/conda/lib/python3.6/site-packages (0.5)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.6/site-packages (from sklearn) (0.21.2)
# Requirement already satisfied: python-dateutil>=2.5.0 in /opt/conda/lib/python3.6/site-packages (from pandas) (2.8.0)
# Requirement already satisfied: numpy>=1.12.0 in /opt/conda/lib/python3.6/site-packages (from pandas) (1.16.2)
# Requirement already satisfied: pytz>=2011k in /opt/conda/lib/python3.6/site-packages (from pandas) (2018.9)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.6/site-packages (from xgboost) (1.1.0)
# Requirement already satisfied: docker>=3.4.1 in /opt/conda/lib/python3.6/site-packages (from fairing) (3.7.2)
# Requirement already satisfied: notebook>=5.6.0 in /opt/conda/lib/python3.6/site-packages (from fairing) (5.7.8)
# Collecting kubernetes>=9.0.0 (from fairing)
#   Downloading https://files.pythonhosted.org/packages/00/f7/4f196c55f1c2713d3edc8252c4b45326306eef4dc10048f13916fe446e2b/kubernetes-9.0.0-py2.py3-none-any.whl (1.4MB)
#     100% |████████████████████████████████| 1.4MB 16.8MB/s ta 0:00:01
# Requirement already satisfied: future>=0.17.1 in /opt/conda/lib/python3.6/site-packages (from fairing) (0.17.1)
# Requirement already satisfied: six>=1.11.0 in /opt/conda/lib/python3.6/site-packages (from fairing) (1.12.0)
# Collecting google-cloud-storage>=1.13.2 (from fairing)
#   Downloading https://files.pythonhosted.org/packages/e2/4e/aee59b19321eb1063317c2e6fa4c2f3cfe21740586de78578eedbd2bed3d/google_cloud_storage-1.16.1-py2.py3-none-any.whl (65kB)
#     100% |████████████████████████████████| 71kB 27.7MB/s ta 0:00:01
# Requirement already satisfied: requests>=2.21.0 in /opt/conda/lib/python3.6/site-packages (from fairing) (2.21.0)
# Requirement already satisfied: setuptools>=34.0.0 in /opt/conda/lib/python3.6/site-packages (from fairing) (40.9.0)
# Collecting google-auth>=1.6.2 (from fairing)
#   Downloading https://files.pythonhosted.org/packages/c5/9b/ed0516cc1f7609fb0217e3057ff4f0f9f3e3ce79a369c6af4a6c5ca25664/google_auth-1.6.3-py2.py3-none-any.whl (73kB)
#     100% |████████████████████████████████| 81kB 26.2MB/s ta 0:00:01
# Requirement already satisfied: httplib2>=0.12.0 in /opt/conda/lib/python3.6/site-packages (from fairing) (0.12.0)
# Collecting oauth2client>=4.0.0 (from fairing)
#   Downloading https://files.pythonhosted.org/packages/95/a9/4f25a14d23f0786b64875b91784607c2277eff25d48f915e39ff0cff505a/oauth2client-4.1.3-py2.py3-none-any.whl (98kB)
#     100% |████████████████████████████████| 102kB 31.0MB/s a 0:00:01
# Requirement already satisfied: tornado<6.0.0,>=5.1.1 in /opt/conda/lib/python3.6/site-packages (from fairing) (5.1.1)
# Requirement already satisfied: google-api-python-client>=1.7.8 in /opt/conda/lib/python3.6/site-packages (from fairing) (1.7.8)
# Requirement already satisfied: cloudpickle>=0.8 in /opt/conda/lib/python3.6/site-packages (from fairing) (0.8.1)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.6/site-packages (from scikit-learn->sklearn) (0.13.2)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.6/site-packages (from docker>=3.4.1->fairing) (0.4.0)
# Requirement already satisfied: websocket-client>=0.32.0 in /opt/conda/lib/python3.6/site-packages (from docker>=3.4.1->fairing) (0.56.0)
# Requirement already satisfied: jupyter-core>=4.4.0 in /opt/conda/lib/python3.6/site-packages (from notebook>=5.6.0->fairing) (4.4.0)
# Requirement already satisfied: pyzmq>=17 in /opt/conda/lib/python3.6/site-packages (from notebook>=5.6.0->fairing) (18.0.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.6/site-packages (from notebook>=5.6.0->fairing) (2.10)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.6/site-packages (from notebook>=5.6.0->fairing) (0.6.0)
# Requirement already satisfied: nbformat in /opt/conda/lib/python3.6/site-packages (from notebook>=5.6.0->fairing) (4.4.0)
# Requirement already satisfied: jupyter-client>=5.2.0 in /opt/conda/lib/python3.6/site-packages (from notebook>=5.6.0->fairing) (5.2.4)
# Requirement already satisfied: terminado>=0.8.1 in /opt/conda/lib/python3.6/site-packages (from notebook>=5.6.0->fairing) (0.8.2)
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.6/site-packages (from notebook>=5.6.0->fairing) (5.1.0)
# Requirement already satisfied: nbconvert in /opt/conda/lib/python3.6/site-packages (from notebook>=5.6.0->fairing) (5.4.1)
# Requirement already satisfied: traitlets>=4.2.1 in /opt/conda/lib/python3.6/site-packages (from notebook>=5.6.0->fairing) (4.3.2)
# Requirement already satisfied: Send2Trash in /opt/conda/lib/python3.6/site-packages (from notebook>=5.6.0->fairing) (1.5.0)
# Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.6/site-packages (from notebook>=5.6.0->fairing) (0.2.0)
# Requirement already satisfied: certifi>=14.05.14 in /opt/conda/lib/python3.6/site-packages (from kubernetes>=9.0.0->fairing) (2019.3.9)
# Requirement already satisfied: requests-oauthlib in /opt/conda/lib/python3.6/site-packages (from kubernetes>=9.0.0->fairing) (1.2.0)
# Requirement already satisfied: pyyaml>=3.12 in /opt/conda/lib/python3.6/site-packages (from kubernetes>=9.0.0->fairing) (3.13)
# Requirement already satisfied: urllib3>=1.23 in /opt/conda/lib/python3.6/site-packages (from kubernetes>=9.0.0->fairing) (1.24.1)
# Requirement already satisfied: google-resumable-media>=0.3.1 in /opt/conda/lib/python3.6/site-packages (from google-cloud-storage>=1.13.2->fairing) (0.3.2)
# Collecting google-cloud-core<2.0dev,>=1.0.0 (from google-cloud-storage>=1.13.2->fairing)
#   Downloading https://files.pythonhosted.org/packages/98/7f/ff56aec313787577e262d5a2e306c04aef61c5c274699ff9fb40095e6691/google_cloud_core-1.0.2-py2.py3-none-any.whl
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests>=2.21.0->fairing) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests>=2.21.0->fairing) (3.0.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.6/site-packages (from google-auth>=1.6.2->fairing) (0.2.4)
# Requirement already satisfied: rsa>=3.1.4 in /opt/conda/lib/python3.6/site-packages (from google-auth>=1.6.2->fairing) (4.0)
# Requirement already satisfied: cachetools>=2.0.0 in /opt/conda/lib/python3.6/site-packages (from google-auth>=1.6.2->fairing) (3.1.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /opt/conda/lib/python3.6/site-packages (from oauth2client>=4.0.0->fairing) (0.4.5)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /opt/conda/lib/python3.6/site-packages (from google-api-python-client>=1.7.8->fairing) (0.0.3)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /opt/conda/lib/python3.6/site-packages (from google-api-python-client>=1.7.8->fairing) (3.0.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.6/site-packages (from jinja2->notebook>=5.6.0->fairing) (1.1.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/conda/lib/python3.6/site-packages (from nbformat->notebook>=5.6.0->fairing) (3.0.1)
# Requirement already satisfied: ptyprocess; os_name != "nt" in /opt/conda/lib/python3.6/site-packages (from terminado>=0.8.1->notebook>=5.6.0->fairing) (0.6.0)
# Requirement already satisfied: ipython>=5.0.0 in /opt/conda/lib/python3.6/site-packages (from ipykernel->notebook>=5.6.0->fairing) (7.4.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/conda/lib/python3.6/site-packages (from nbconvert->notebook>=5.6.0->fairing) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.6/site-packages (from nbconvert->notebook>=5.6.0->fairing) (1.4.2)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.6/site-packages (from nbconvert->notebook>=5.6.0->fairing) (0.5.0)
# Requirement already satisfied: mistune>=0.8.1 in /opt/conda/lib/python3.6/site-packages (from nbconvert->notebook>=5.6.0->fairing) (0.8.4)
# Requirement already satisfied: pygments in /opt/conda/lib/python3.6/site-packages (from nbconvert->notebook>=5.6.0->fairing) (2.3.1)
# Requirement already satisfied: testpath in /opt/conda/lib/python3.6/site-packages (from nbconvert->notebook>=5.6.0->fairing) (0.4.2)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.6/site-packages (from nbconvert->notebook>=5.6.0->fairing) (3.1.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.6/site-packages (from traitlets>=4.2.1->notebook>=5.6.0->fairing) (4.4.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.6/site-packages (from requests-oauthlib->kubernetes>=9.0.0->fairing) (3.0.1)
# Collecting google-api-core<2.0.0dev,>=1.11.0 (from google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage>=1.13.2->fairing)
#   Downloading https://files.pythonhosted.org/packages/10/d6/8b1e8d79a8a56649af3a094e3d90dd213278da942f36d831b57c0ca4a503/google_api_core-1.11.1-py2.py3-none-any.whl (66kB)
#     100% |████████████████████████████████| 71kB 18.8MB/s ta 0:00:01
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=5.6.0->fairing) (19.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=5.6.0->fairing) (0.14.11)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel->notebook>=5.6.0->fairing) (0.1.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /opt/conda/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel->notebook>=5.6.0->fairing) (4.6.0)
# Requirement already satisfied: jedi>=0.10 in /opt/conda/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel->notebook>=5.6.0->fairing) (0.13.3)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /opt/conda/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel->notebook>=5.6.0->fairing) (2.0.9)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel->notebook>=5.6.0->fairing) (0.7.5)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.6/site-packages (from bleach->nbconvert->notebook>=5.6.0->fairing) (0.5.1)
# Requirement already satisfied: protobuf>=3.4.0 in /opt/conda/lib/python3.6/site-packages (from google-api-core<2.0.0dev,>=1.11.0->google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage>=1.13.2->fairing) (3.7.1)
# Requirement already satisfied: googleapis-common-protos!=1.5.4,<2.0dev,>=1.5.3 in /opt/conda/lib/python3.6/site-packages (from google-api-core<2.0.0dev,>=1.11.0->google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage>=1.13.2->fairing) (1.5.9)
# Requirement already satisfied: parso>=0.3.0 in /opt/conda/lib/python3.6/site-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel->notebook>=5.6.0->fairing) (0.4.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.6/site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->notebook>=5.6.0->fairing) (0.1.7)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Stored in directory: /home/jovyan/.cache/pip/wheels/76/03/bb/589d421d27431bcd2c6da284d5f2286c8e3b2ea3cf1594c074
# Successfully built sklearn
# kfp 0.1 has requirement google-auth==1.6.1, but you'll have google-auth 1.6.3 which is incompatible.
# kfp 0.1 has requirement google-cloud-storage==1.13.0, but you'll have google-cloud-storage 1.16.1 which is incompatible.
# kfp 0.1 has requirement kubernetes==8.0.0, but you'll have kubernetes 9.0.0 which is incompatible.
# google-cloud-bigquery 1.6.1 has requirement google-cloud-core<0.30dev,>=0.28.0, but you'll have google-cloud-core 1.0.2 which is incompatible.
# apache-beam 2.13.0 has requirement oauth2client<4,>=2.0.1, but you'll have oauth2client 4.1.3 which is incompatible.
# Installing collected packages: sklearn, google-auth, kubernetes, google-api-core, google-cloud-core, google-cloud-storage, oauth2client
#   Found existing installation: google-auth 1.6.1
#     Uninstalling google-auth-1.6.1:
#       Successfully uninstalled google-auth-1.6.1
#   Found existing installation: kubernetes 8.0.0
#     Uninstalling kubernetes-8.0.0:
#       Successfully uninstalled kubernetes-8.0.0
#   Found existing installation: google-api-core 1.9.0
#     Uninstalling google-api-core-1.9.0:
#       Successfully uninstalled google-api-core-1.9.0
#   Found existing installation: google-cloud-core 0.28.1
#     Uninstalling google-cloud-core-0.28.1:
#       Successfully uninstalled google-cloud-core-0.28.1
#   Found existing installation: google-cloud-storage 1.13.0
#     Uninstalling google-cloud-storage-1.13.0:
#       Successfully uninstalled google-cloud-storage-1.13.0
#   Found existing installation: oauth2client 3.0.0
#     Uninstalling oauth2client-3.0.0:
#       Successfully uninstalled oauth2client-3.0.0
# Successfully installed google-api-core-1.11.1 google-auth-1.6.3 google-cloud-core-1.0.2 google-cloud-storage-1.16.1 kubernetes-9.0.0 oauth2client-4.1.3 sklearn-0.0
# You are using pip version 19.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import argparse
import logging
import pandas as pd
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import Imputer
from xgboost import XGBRegressor
import urllib.request


TRAINING_URL="https://raw.githubusercontent.com/kubeflow/examples/master/xgboost_ames_housing/ames_dataset/train.csv"
TRAINING_FILE="train.csv"

ESTIMATORS=1000
LEARNING_RATE=0.1
TEST_FRACTION_SIZE=0.25
EARLY_STOPPING_ROUNDS=50

def run_training_and_eval():
    (train_X, train_y), (test_X, test_y) = read_input()
    model = train_model(train_X,
                        train_y,
                        test_X,
                        test_y,
                        ESTIMATORS,
                        LEARNING_RATE)

    eval_model(model, test_X, test_y)

def download(url, file_name):
    with urllib.request.urlopen(url) as response, open(file_name, "wb") as file:
        file.write(response.read())

def read_input(test_size=TEST_FRACTION_SIZE):
    """Read input data and split it into train and test."""
    download(TRAINING_URL, TRAINING_FILE)
    data = pd.read_csv(TRAINING_FILE)
    data.dropna(axis=0, subset=['SalePrice'], inplace=True)

    y = data.SalePrice
    X = data.drop(['SalePrice'], axis=1).select_dtypes(exclude=['object'])

    train_X, test_X, train_y, test_y = train_test_split(X.values,
                                                        y.values,
                                                        test_size=test_size,
                                                        shuffle=False)

    imputer = Imputer()
    train_X = imputer.fit_transform(train_X)
    test_X = imputer.transform(test_X)

    return (train_X, train_y), (test_X, test_y)

def train_model(train_X,
                train_y,
                test_X,
                test_y,
                n_estimators,
                learning_rate):
    """Train the model using XGBRegressor."""
    model = XGBRegressor(n_estimators=n_estimators,
                      learning_rate=learning_rate)

    model.fit(train_X,
              train_y,
              early_stopping_rounds=EARLY_STOPPING_ROUNDS,
              eval_set=[(test_X, test_y)])

    logging.info("Best RMSE on eval: %.2f with %d rounds",
                 model.best_score,
                 model.best_iteration+1)
    return model

def eval_model(model, test_X, test_y):
    """Evaluate the model performance."""
    predictions = model.predict(test_X)
    logging.info("mean_absolute_error=%.2f", mean_absolute_error(predictions, test_y))

# %%
import fairing
run_training_and_eval = fairing.config.fn(run_training_and_eval)
run_training_and_eval()
# Out:
# Building image...
# /opt/conda/lib/python3.6/site-packages/fairing/__init__.py already exists in Fairing context, skipping...
# Loading Docker credentials for repository 'gcr.io/kubeflow-images-public/fairing:dev'
# Invoking 'docker-credential-gcloud' to obtain Docker credentials.
# Successfully obtained Docker credentials.
# Image successfully built in 0.6095852610014845s.
# Pushing image gcr.io/pipelineai2/fairing-job:7ABA4B88...
# Loading Docker credentials for repository 'gcr.io/pipelineai2/fairing-job:7ABA4B88'
# Invoking 'docker-credential-gcloud' to obtain Docker credentials.
# Successfully obtained Docker credentials.
# Uploading gcr.io/pipelineai2/fairing-job:7ABA4B88
# Layer sha256:830c3b063b0f1cffb88718599fbfdadb89d1c857fcb168920315be8a438d1976 exists, skipping
# Layer sha256:c7849095338ab97d368a10ead4c5e4e63a64b87244988af729a8e15840d1fd17 exists, skipping
# Layer sha256:fa3f2f277e67c5cbbf1dac21dc27111a60d3cd2ef494d94aa1515d3319f2a245 exists, skipping
# Layer sha256:398d32b153e84fe343f0c5b07d65e89b05551aae6cb8b3a03bb2b662976eb3b8 exists, skipping
# Layer sha256:8a9f4b24773fe65ca06daa3a7395a761b8b97a98bf8991bf30bea18241090298 exists, skipping
# Layer sha256:8277d19d91e622ebfbe8a2ea705157e6c69c32a38da827f2328b4b99ef2a9531 exists, skipping
# Layer sha256:9d866f8bde2a0d607a6d17edc0fbd5e00b58306efc2b0a57e0ba72f269e7c6be exists, skipping
# Layer sha256:b30688a685ae81af14def6b3fa7ce58a256a15518142fd08b640f0929bb3de7b exists, skipping
# Layer sha256:c3eee3f9faa37af15a7bb6d15015499eddedd462b9a842b1cea9c325c41144da exists, skipping
# Layer sha256:124c757242f88002a858c23fc79f8262f9587fa30fd92507e586ad074afb42b6 exists, skipping
# Layer sha256:2bd471d901800ba6a56a11b1f1037d83b2b8f3ed2a33c3db221b125250f4a057 exists, skipping
# Layer sha256:2371acf66e480f57589624ebb820ecfcbbe8f1a37baa33ba07ec539cf3cc4d30 exists, skipping
# Layer sha256:5fe8ba8cdba8c0d4cc5d74ecc833b6866ae41a53a2819d97ba786ff6f8ace86f exists, skipping
# Layer sha256:0f2f739d007001df0b36e011dd15f09849b4e4e55011f6150fce45ec58978419 exists, skipping
# Layer sha256:92ac723b861941bb0664c9173be844ad7ad7c91d2f6ff25fa3e956f13ae1f88a exists, skipping
# Layer sha256:2aa8ad8d57d0bce2ce44d11fabe4a26d3cd3b9b0759ecfe97376fcc9164d0288 exists, skipping
# Layer sha256:055f1d44be0f1eb26ff27c3d879c20cdb918b19391dcea4230371649133d405f exists, skipping
# Layer sha256:972186692e64b0c0cf7d4b2f227bbce3af40735684c4790509a9109f8e5de873 exists, skipping
# Layer sha256:b3a26937b826052d75598c640cb2027cdc22c0a6e6f6746e5c2d9daad64412c6 exists, skipping
# Layer sha256:d61002581bf49d6247429715b7119766c7ffd67432bef02085625ed8d351c0a1 exists, skipping
# Layer sha256:8fc0a11e62a8be9cc08d9690f7b11119a9a64caf7fd8eedc569acf211e3bcbe6 exists, skipping
# Layer sha256:afde35469481d2bc446d649a7a3d099147bbf7696b66333e76a411686b617ea1 exists, skipping
# Layer sha256:23a498561802166d7ae893dc6daecd5487c5e914f0c8be8794021a799d8d6ead pushed.
# Layer sha256:6693c84d1d8fcab91720b29a2a224d26a98ab486ad537c8551b885ab92257df8 pushed.
# Finished upload of: gcr.io/pipelineai2/fairing-job:7ABA4B88
# Pushed image gcr.io/pipelineai2/fairing-job:7ABA4B88 in 2.060670367001876s.
# Training job fairing-job-9zmbk launched.
# Waiting for fairing-job-9zmbk-fhrg6 to start...
# Waiting for fairing-job-9zmbk-fhrg6 to start...
# Pod started running True
# [0]	validation_0-rmse:177514
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [1]	validation_0-rmse:161858
# [2]	validation_0-rmse:147237
# [3]	validation_0-rmse:134132
# [4]	validation_0-rmse:122224
# [5]	validation_0-rmse:111538
# [6]	validation_0-rmse:102142
# [7]	validation_0-rmse:93392.2
# [8]	validation_0-rmse:85824.6
# [9]	validation_0-rmse:79667.6
# [10]	validation_0-rmse:73463.4
# [11]	validation_0-rmse:68059.4
# [12]	validation_0-rmse:63350.5
# [13]	validation_0-rmse:59732.1
# [14]	validation_0-rmse:56260.7
# [15]	validation_0-rmse:53392.6
# [16]	validation_0-rmse:50770.8
# [17]	validation_0-rmse:48107.8
# [18]	validation_0-rmse:45923.9
# [19]	validation_0-rmse:44154.2
# [20]	validation_0-rmse:42488.1
# [21]	validation_0-rmse:41263.3
# [22]	validation_0-rmse:40212.8
# [23]	validation_0-rmse:39089.1
# [24]	validation_0-rmse:37691.1
# [25]	validation_0-rmse:36875.2
# [26]	validation_0-rmse:36276.2
# [27]	validation_0-rmse:35444.1
# [28]	validation_0-rmse:34831.5
# [29]	validation_0-rmse:34205.4
# [30]	validation_0-rmse:33831.9
# [31]	validation_0-rmse:33183.7
# [32]	validation_0-rmse:33019.4
# [33]	validation_0-rmse:32680
# [34]	validation_0-rmse:32438.5
# [35]	validation_0-rmse:32130.4
# [36]	validation_0-rmse:31644.2
# [37]	validation_0-rmse:31248.8
# [38]	validation_0-rmse:31059.8
# [39]	validation_0-rmse:30862.4
# [40]	validation_0-rmse:30754
# [41]	validation_0-rmse:30561.6
# [42]	validation_0-rmse:30416.9
# [43]	validation_0-rmse:30156.4
# [44]	validation_0-rmse:29853
# [45]	validation_0-rmse:29486.6
# [46]	validation_0-rmse:29158.8
# [47]	validation_0-rmse:29017
# [48]	validation_0-rmse:28973.9
# [49]	validation_0-rmse:28787.7
# [50]	validation_0-rmse:28652.4
# [51]	validation_0-rmse:28572.8
# [52]	validation_0-rmse:28507
# [53]	validation_0-rmse:28279.1
# [54]	validation_0-rmse:28235.7
# [55]	validation_0-rmse:28187.3
# [56]	validation_0-rmse:28163.3
# [57]	validation_0-rmse:28130.7
# [58]	validation_0-rmse:28075.2
# [59]	validation_0-rmse:28034.8
# [60]	validation_0-rmse:27918.4
# [61]	validation_0-rmse:27921.8
# [62]	validation_0-rmse:27782.7
# [63]	validation_0-rmse:27696
# [64]	validation_0-rmse:27652
# [65]	validation_0-rmse:27623.1
# [66]	validation_0-rmse:27550.9
# [67]	validation_0-rmse:27519.3
# [68]	validation_0-rmse:27482.8
# [69]	validation_0-rmse:27333.7
# [70]	validation_0-rmse:27276.4
# [71]	validation_0-rmse:27270.7
# [72]	validation_0-rmse:27243
# [73]	validation_0-rmse:27233.8
# [74]	validation_0-rmse:27256.9
# [75]	validation_0-rmse:27228.5
# [76]	validation_0-rmse:27151.1
# [77]	validation_0-rmse:27064.4
# [78]	validation_0-rmse:27028.6
# [79]	validation_0-rmse:27028.6
# [80]	validation_0-rmse:27008.6
# [81]	validation_0-rmse:27011
# [82]	validation_0-rmse:26997
# [83]	validation_0-rmse:26933.3
# [84]	validation_0-rmse:26920.6
# [85]	validation_0-rmse:26917.8
# [86]	validation_0-rmse:26903.4
# [87]	validation_0-rmse:26885.1
# [88]	validation_0-rmse:26858.6
# [89]	validation_0-rmse:26859.2
# [90]	validation_0-rmse:26773.6
# [91]	validation_0-rmse:26760.8
# [92]	validation_0-rmse:26714.3
# [93]	validation_0-rmse:26702.5
# [94]	validation_0-rmse:26692.9
# [95]	validation_0-rmse:26669.6
# [96]	validation_0-rmse:26607.3
# [97]	validation_0-rmse:26591.4
# [98]	validation_0-rmse:26635.9
# [99]	validation_0-rmse:26559.1
# [100]	validation_0-rmse:26544.6
# [101]	validation_0-rmse:26564.3
# [102]	validation_0-rmse:26651.1
# [103]	validation_0-rmse:26635
# [104]	validation_0-rmse:26655.5
# [105]	validation_0-rmse:26634.6
# [106]	validation_0-rmse:26575.1
# [107]	validation_0-rmse:26508.9
# [108]	validation_0-rmse:26516.2
# [109]	validation_0-rmse:26558
# [110]	validation_0-rmse:26547.6
# [111]	validation_0-rmse:26531.6
# [112]	validation_0-rmse:26522.4
# [113]	validation_0-rmse:26506.4
# [114]	validation_0-rmse:26499.6
# [115]	validation_0-rmse:26492.6
# [116]	validation_0-rmse:26529.6
# [117]	validation_0-rmse:26484.9
# [118]	validation_0-rmse:26479.1
# [119]	validation_0-rmse:26483.3
# [120]	validation_0-rmse:26546.7
# [121]	validation_0-rmse:26527.2
# [122]	validation_0-rmse:26496.2
# [123]	validation_0-rmse:26486.1
# [124]	validation_0-rmse:26447.1
# [125]	validation_0-rmse:26416.2
# [126]	validation_0-rmse:26399.4
# [127]	validation_0-rmse:26346.4
# [128]	validation_0-rmse:26343
# [129]	validation_0-rmse:26334.4
# [130]	validation_0-rmse:26323.2
# [131]	validation_0-rmse:26305.6
# [132]	validation_0-rmse:26297.9
# [133]	validation_0-rmse:26262.8
# [134]	validation_0-rmse:26266
# [135]	validation_0-rmse:26271.1
# [136]	validation_0-rmse:26253.2
# [137]	validation_0-rmse:26203.7
# [138]	validation_0-rmse:26217.2
# [139]	validation_0-rmse:26206.4
# [140]	validation_0-rmse:26281
# [141]	validation_0-rmse:26292.4
# [142]	validation_0-rmse:26293.5
# [143]	validation_0-rmse:26279.2
# [144]	validation_0-rmse:26272.7
# [145]	validation_0-rmse:26230.4
# [146]	validation_0-rmse:26187.3
# [147]	validation_0-rmse:26178.2
# [148]	validation_0-rmse:26152.8
# [149]	validation_0-rmse:26170.4
# [150]	validation_0-rmse:26131.7
# [151]	validation_0-rmse:26256
# [152]	validation_0-rmse:26244.8
# [153]	validation_0-rmse:26242.4
# [154]	validation_0-rmse:26222.9
# [155]	validation_0-rmse:26241.8
# [156]	validation_0-rmse:26253.2
# [157]	validation_0-rmse:26224.9
# [158]	validation_0-rmse:26220.1
# [159]	validation_0-rmse:26201.5
# [160]	validation_0-rmse:26146.6
# [161]	validation_0-rmse:26127
# [162]	validation_0-rmse:26138.9
# [163]	validation_0-rmse:26119.6
# [164]	validation_0-rmse:26131.2
# [165]	validation_0-rmse:26125.9
# [166]	validation_0-rmse:26142.3
# [167]	validation_0-rmse:26145.7
# [168]	validation_0-rmse:26134.9
# [169]	validation_0-rmse:26132.8
# [170]	validation_0-rmse:26121
# [171]	validation_0-rmse:26106.8
# [172]	validation_0-rmse:26098.8
# [173]	validation_0-rmse:26082.6
# [174]	validation_0-rmse:26080.9
# [175]	validation_0-rmse:26086.1
# [176]	validation_0-rmse:26069.6
# [177]	validation_0-rmse:26080.7
# [178]	validation_0-rmse:26076.8
# [179]	validation_0-rmse:26067.3
# [180]	validation_0-rmse:26068
# [181]	validation_0-rmse:26065.6
# [182]	validation_0-rmse:26056.1
# [183]	validation_0-rmse:26027.8
# [184]	validation_0-rmse:26029.2
# [185]	validation_0-rmse:26017.2
# [186]	validation_0-rmse:26027.2
# [187]	validation_0-rmse:26028.7
# [188]	validation_0-rmse:26032.3
# [189]	validation_0-rmse:26032
# [190]	validation_0-rmse:26024.6
# [191]	validation_0-rmse:26024
# [192]	validation_0-rmse:26037.1
# [193]	validation_0-rmse:26009.7
# [194]	validation_0-rmse:25996.5
# [195]	validation_0-rmse:25986.9
# [196]	validation_0-rmse:25997.8
# [197]	validation_0-rmse:25984.6
# [198]	validation_0-rmse:25971.5
# [199]	validation_0-rmse:25957.9
# [200]	validation_0-rmse:25958.4
# [201]	validation_0-rmse:25968.7
# [202]	validation_0-rmse:25965.5
# [203]	validation_0-rmse:25946
# [204]	validation_0-rmse:25943.5
# [205]	validation_0-rmse:25947.8
# [206]	validation_0-rmse:25941.8
# [207]	validation_0-rmse:25938.6
# [208]	validation_0-rmse:25909.7
# [209]	validation_0-rmse:25911.1
# [210]	validation_0-rmse:25894.8
# [211]	validation_0-rmse:25875.3
# [212]	validation_0-rmse:25888.7
# [213]	validation_0-rmse:25877.3
# [214]	validation_0-rmse:25875.4
# [215]	validation_0-rmse:25883.2
# [216]	validation_0-rmse:25855.3
# [217]	validation_0-rmse:25855.5
# [218]	validation_0-rmse:25868.6
# [219]	validation_0-rmse:25867
# [220]	validation_0-rmse:25940.8
# [221]	validation_0-rmse:25952.6
# [222]	validation_0-rmse:25953
# [223]	validation_0-rmse:25952.4
# [224]	validation_0-rmse:25964.4
# [225]	validation_0-rmse:25963
# [226]	validation_0-rmse:25960.6
# [227]	validation_0-rmse:25959.4
# [228]	validation_0-rmse:25949
# [229]	validation_0-rmse:25931.6
# [230]	validation_0-rmse:25919.3
# [231]	validation_0-rmse:25891.3
# [232]	validation_0-rmse:25885.8
# [233]	validation_0-rmse:25897.9
# [234]	validation_0-rmse:25909.7
# [235]	validation_0-rmse:25987.2
# [236]	validation_0-rmse:25980.8
# [237]	validation_0-rmse:25982.7
# [238]	validation_0-rmse:25935.8
# [239]	validation_0-rmse:25922.4
# [240]	validation_0-rmse:25921.3
# [241]	validation_0-rmse:25923.5
# [242]	validation_0-rmse:25915.4
# [243]	validation_0-rmse:25918.4
# [244]	validation_0-rmse:25914
# [245]	validation_0-rmse:25901.4
# [246]	validation_0-rmse:25890.6
# [247]	validation_0-rmse:25883.6
# [248]	validation_0-rmse:25894.1
# [249]	validation_0-rmse:25870
# [250]	validation_0-rmse:25871.3
# [251]	validation_0-rmse:25855.9
# [252]	validation_0-rmse:25855.8
# [253]	validation_0-rmse:25828
# [254]	validation_0-rmse:25828.1
# [255]	validation_0-rmse:25834.7
# [256]	validation_0-rmse:25830.7
# [257]	validation_0-rmse:25838.2
# [258]	validation_0-rmse:25836.8
# [259]	validation_0-rmse:25833.2
# [260]	validation_0-rmse:25817
# [261]	validation_0-rmse:25807.4
# [262]	validation_0-rmse:25822.1
# [263]	validation_0-rmse:25825.6
# [264]	validation_0-rmse:25895.4
# [265]	validation_0-rmse:25897.1
# [266]	validation_0-rmse:25890
# [267]	validation_0-rmse:25892.4
# [268]	validation_0-rmse:25868.7
# [269]	validation_0-rmse:25867.7
# [270]	validation_0-rmse:25868
# [271]	validation_0-rmse:25863.2
# [272]	validation_0-rmse:25865.8
# [273]	validation_0-rmse:25855.9
# [274]	validation_0-rmse:25843
# [275]	validation_0-rmse:25824.7
# [276]	validation_0-rmse:25847.8
# [277]	validation_0-rmse:25844.6
# [278]	validation_0-rmse:25859.6
# [279]	validation_0-rmse:25871.1
# [280]	validation_0-rmse:25917.8
# [281]	validation_0-rmse:25923.1
# [282]	validation_0-rmse:25921.1
# [283]	validation_0-rmse:25928.6
# [284]	validation_0-rmse:25932.3
# [285]	validation_0-rmse:25904.3
# [286]	validation_0-rmse:25910.4
# [287]	validation_0-rmse:25893.4
# [288]	validation_0-rmse:25894.5
# [289]	validation_0-rmse:25892.6
# [290]	validation_0-rmse:25887.8
# [291]	validation_0-rmse:25867.1
# [292]	validation_0-rmse:25851.8
# [293]	validation_0-rmse:25833.7
# [294]	validation_0-rmse:25833.1
# [295]	validation_0-rmse:25836.5
# [296]	validation_0-rmse:25838.7
# [297]	validation_0-rmse:25823.3
# [298]	validation_0-rmse:25822.3
# [299]	validation_0-rmse:25825.7
# [300]	validation_0-rmse:25843.1
# [301]	validation_0-rmse:25845.1
# [302]	validation_0-rmse:25829.4
# [303]	validation_0-rmse:25844.6
# [304]	validation_0-rmse:25860.2
# [305]	validation_0-rmse:25864.1
# [306]	validation_0-rmse:25863
# [307]	validation_0-rmse:25868.9
# [308]	validation_0-rmse:25873.9
# [309]	validation_0-rmse:25869.3
# [310]	validation_0-rmse:25872.8
# [311]	validation_0-rmse:25880.3
# Stopping. Best iteration:
# [261]	validation_0-rmse:25807.4
#
# /opt/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /opt/conda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# Best RMSE on eval: 25807.43 with 262 rounds
# mean_absolute_error=17212.85
# Cleaning up job fairing-job-9zmbk...
